# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"car data.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print(data['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
print(data['Seller_Type'].unique())
print(data['Transmission'].unique())
print(data['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
# checking  missing values
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_data=data[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_data['Current_Year']=2021

# %%
final_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2021
# 1       Manual      0          2021
# 2       Manual      0          2021
# 3       Manual      0          2021
# 4       Manual      0          2021

# %%
final_data['No_year'] = final_data['Current_Year'] - final_data['Year']

# %%
final_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  No_year
# 0       Manual      0          2021        7
# 1       Manual      0          2021        8
# 2       Manual      0          2021        4
# 3       Manual      0          2021       10
# 4       Manual      0          2021        7

# %%
final_data.drop(columns=['Year','Current_Year'],inplace=True)

# %%
final_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  No_year
# 0       Manual      0        7
# 1       Manual      0        8
# 2       Manual      0        4
# 3       Manual      0       10
# 4       Manual      0        7

# %%
#Apply one hot encoding
final_data = pd.get_dummies(final_data,drop_first=True)

# %%
final_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_year  Fuel_Type_Diesel  \
# 0           3.35           5.59       27000      0        7                 0
# 1           4.75           9.54       43000      0        8                 1
# 2           7.25           9.85        6900      0        4                 0
# 3           2.85           4.15        5200      0       10                 0
# 4           4.60           6.87       42450      0        7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
sns.pairplot(final_data)

# %%
sns.heatmap(final_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Splitting the data 
X = final_data.iloc[:,1:]
y= final_data.iloc[:,0]

# %%
##feature importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.33122355 0.03823298 0.0014307  0.07504894 0.25248134 0.00370914
#  0.13548741 0.16238595]

# %%
f_imp = pd.Series(model.feature_importances_,index = X.columns)
f_imp.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#      Present_Price  Kms_Driven  Owner  No_year  Fuel_Type_Diesel  \
# 185           0.58        1900      0       13                 0
# 72           18.61       56001      0        8                 0
# 15           10.79       43000      0        5                 1
# 10            3.60        2135      0        4                 0
# 196           0.52      500000      0       13                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 185                 1                       1                    0
# 72                  1                       0                    1
# 15                  0                       0                    1
# 10                  1                       0                    1
# 196                 1                       1                    0

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(i) for i in np.linspace(start = 100, stop = 1200, num = 200)]
max_depth = [int(i) for i in np.linspace(5,30,num = 6)]
max_features = ['auto' , 'sqrt']
min_samples_split = [2,5,10,15,100]
min_samples_leaf = [1,2,5,10]

# %%
random_grid = {'n_estimators':n_estimators,
               'max_features':max_features,
               'max_depth':max_depth,
               'min_samples_split':min_samples_split,
               'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 105, 111, 116, 122, 127, 133, 138, 144, 149, 155, 160, 166, 171, 177, 182, 188, 193, 199, 205, 210, 216, 221, 227, 232, 238, 243, 249, 254, 260, 265, 271, 276, 282, 287, 293, 298, 304, 310, 315, 321, 326, 332, 337, 343, 348, 354, 359, 365, 370, 376, 381, 387, 392, 398, 404, 409, 415, 420, 426, 431, 437, 442, 448, 453, 459, 464, 470, 475, 481, 486, 492, 497, 503, 509, 514, 520, 525, 531, 536, 542, 547, 553, 558, 564, 569, 575, 580, 586, 591, 597, 603, 608, 614, 619, 625, 630, 636, 641, 647, 652, 658, 663, 669, 674, 680, 685, 691, 696, 702, 708, 713, 719, 724, 730, 735, 741, 746, 752, 757, 763, 768, 774, 779, 785, 790, 796, 802, 807, 813, 818, 824, 829, 835, 840, 846, 851, 857, 862, 868, 873, 879, 884, 890, 895, 901, 907, 912, 918, 923, 929, 934, 940, 945, 951, 956, 962, 967, 973, 978, 984, 989, 995, 1001, 1006, 1012, 1017, 1023, 1028, 1034, 1039, 1045, 1050, 1056, 1061, 1067, 1072, 1078, 1083, 1089, 1094, 1100, 1106, 1111, 1117, 1122, 1128, 1133, 1139, 1144, 1150, 1155, 1161, 1166, 1172, 1177, 1183, 1188, 1194, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring = 'neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1177; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1177; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1177; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1177; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1177; total time=   1.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=431; total time=   0.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=431; total time=   0.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=431; total time=   0.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=431; total time=   0.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=431; total time=   0.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=973; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=973; total time=   0.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=973; total time=   1.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=973; total time=   1.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=973; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=829; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=829; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=829; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=829; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=829; total time=   0.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=564; total time=   0.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=564; total time=   0.8s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=564; total time=   0.8s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=564; total time=   0.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=564; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=459; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=376; total time=   0.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=376; total time=   0.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=376; total time=   0.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=376; total time=   0.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=376; total time=   0.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1172; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1172; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1172; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1172; total time=   1.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1172; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=995; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=995; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=995; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=995; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=995; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1155; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1155; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1155; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1155; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1155; total time=   1.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 105, 111, 116,
#                                                          122, 127, 133, 138,
#                                                          144, 149, 155, 160,
#                                                          166, 171, 177, 182,
#                                                          188, 193, 199, 205,
#                                                          210, 216, 221, 227,
#                                                          232, 238, 243, 249,
#                                                          254, 260, ...]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(max_depth=25, max_features='sqrt', min_samples_leaf=2,
#                       n_estimators=1172)

# %%
pred = rf_random.predict(X_test)

# %%
pred
# Out:
# array([ 1.08294083,  9.04902354,  6.1174661 ,  0.6042055 ,  6.3831118 ,
#         6.92171572,  1.04094064,  0.71371423,  0.70446317,  6.51769566,
#         9.94469138,  0.91231662,  6.3280656 ,  1.04635783,  5.99881943,
#         3.03055938,  0.97401434,  9.15291486,  0.82849656,  1.44000098,
#         0.62498552,  8.82233313,  6.69625096,  2.9846473 ,  0.66926963,
#         3.99622965,  5.02096827,  3.54922768,  1.23998757,  1.11594629,
#         0.72226491,  9.28385164,  0.5383059 ,  3.16544755,  8.26055933,
#         4.37796004,  5.6126798 ,  4.63599559,  3.08059191,  5.23241734,
#         4.27680286,  4.22694435,  4.6557648 ,  0.71026967,  7.51181039,
#         0.69229194,  6.64843498,  5.51148646,  3.20985835,  5.42165034,
#         5.24194912,  1.35021077, 19.72865482, 19.17761586,  7.06593107,
#         7.86517842,  5.04982744,  9.2463963 ,  3.1921963 ,  6.47743856,
#         0.48343308,  0.51661104,  1.01798516,  0.43351018,  4.71126234,
#         1.17172234, 19.25457377, 19.07871215,  6.01360934,  0.60584819,
#         5.47866516,  4.19075545,  5.85877694,  4.70955536,  3.05171996,
#         1.05021908,  0.91535504,  7.50126053,  0.66578123,  8.07177018,
#         5.15109558,  3.71271675, 10.27357578,  9.07228913,  2.69142688,
#         0.99207532,  1.07425668,  3.53815283,  0.75136389, 17.81604346,
#         1.1237292 ])

# %%
sns.distplot(y_test-pred)
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test,pred)

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle
# ERROR: No matching distribution found for pickle

# %%
import pickle 
file = open('random_forest_regression_model.pkl','wb')

pickle.dump(rf_random,file)
